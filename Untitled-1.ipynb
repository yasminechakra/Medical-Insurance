# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("harishkumardatalab/medical-insurance-price-prediction")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("harishkumardatalab/medical-insurance-price-prediction")
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Medical_insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200
#
# [2772 rows x 7 columns]

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  2772.000000  2772.000000  2772.000000   2772.000000
# mean     39.109668    30.701349     1.101732  13261.369959
# std      14.081459     6.129449     1.214806  12151.768945
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    26.220000     0.000000   4687.797000
# 50%      39.000000    30.447500     1.000000   9333.014350
# 75%      51.000000    34.770000     2.000000  16577.779500
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2772 non-null   int64
#  1   sex       2772 non-null   object
#  2   bmi       2772 non-null   float64
#  3   children  2772 non-null   int64
#  4   smoker    2772 non-null   object
#  5   region    2772 non-null   object
#  6   charges   2772 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 151.7+ KB

# %%
#check if there are missing values
missing_data = df.isnull()
missing_data.head(10)
# Out:
#      age    sex    bmi  children  smoker  region  charges
# 0  False  False  False     False   False   False    False
# 1  False  False  False     False   False   False    False
# 2  False  False  False     False   False   False    False
# 3  False  False  False     False   False   False    False
# 4  False  False  False     False   False   False    False
# 5  False  False  False     False   False   False    False
# 6  False  False  False     False   False   False    False
# 7  False  False  False     False   False   False    False
# 8  False  False  False     False   False   False    False
# 9  False  False  False     False   False   False    False

# %%
#count missing values in each column
for column in missing_data.columns.values.tolist():
    print (column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# age
# age
# False    2772
# Name: count, dtype: int64
#
# sex
# sex
# False    2772
# Name: count, dtype: int64
#
# bmi
# bmi
# False    2772
# Name: count, dtype: int64
#
# children
# children
# False    2772
# Name: count, dtype: int64
#
# smoker
# smoker
# False    2772
# Name: count, dtype: int64
#
# region
# region
# False    2772
# Name: count, dtype: int64
#
# charges
# charges
# False    2772
# Name: count, dtype: int64

# %% [markdown]
# there are no missing values in this data frame

# %%
#Analyzing Individual Features Patterns Using Visualization 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#positive linear relationship
sns.regplot(x="bmi", y="age", data=df)
plt.ylim(0,)
# Out:
# (0.0, 66.3)

# %%
sns.regplot(x="charges", y="age", data=df)
# Out:
# <Axes: xlabel='charges', ylabel='age'>

# %%
sns.regplot(x="charges", y="bmi", data=df)
# Out:
# <Axes: xlabel='charges', ylabel='bmi'>

# %%
sns.regplot(x="children", y="charges", data=df)
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %%
#specific attribute correlation 
SAC = df[['bmi','charges']].corr()
SAC
# Out:
#               bmi   charges
# bmi      1.000000  0.199846
# charges  0.199846  1.000000

# %%
#scatter plot
plt.scatter(df[["children"]], df[["charges"]])

# %%
#REGRESSION PLOT 
sns.boxplot(x="children",y="charges", data=df)
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %%
#box plot 
sns.regplot(x="children",y="charges", data=df)
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %%
#groupby attribute 
df_group = df[["children", "charges"]]

# %%
#groupby statements#####################################################################################
df_group = df_group.groupby(["charges"],as_index=False).mean()

df_group = df_group.groupby(["Children", "charges"], as_index=False).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 4
#       1 #groupby statements#####################################################################################
#       2 df_group = df_group.groupby(["charges"],as_index=False).mean()
# ----> 4 df_group = df_group.groupby(["Children", "charges"], as_index=False).mean()
#
# File c:\Users\ychakra\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
# ...

# %%
import seaborn as sns

# %% [markdown]
# #### Data Processing

# %%
#encoding categorical variables (sex, smoker, region) into numerical format
#encoding the sex column bu assigning numerical values to the categories male and female

#label encode the "sex" column (Label Encoding)
df["sex"] = df["sex"].map({"male" : 0, "female" : 1})

#verify the encoding 
print(df["sex"].head())
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: sex, dtype: int64

# %%
#encoding the smoker column
df["smoker"] = df["smoker"].map({"yes" : 1, "no" : 0})

#verify the encoding
print(df["smoker"].head())
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: smoker, dtype: int64

# %%
#One-Hot Encoding for the "region" column
df = pd.get_dummies(df, columns = ["region"], prefix= "region")

print(df.head())
# Out:
#    age  sex     bmi  children  smoker      charges  region_northeast  \
# 0   19    1  27.900         0       1  16884.92400             False
# 1   18    0  33.770         1       0   1725.55230             False
# 2   28    0  33.000         3       0   4449.46200             False
# 3   33    0  22.705         0       0  21984.47061             False
# 4   32    0  28.880         0       0   3866.85520             False
#
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker      charges  region_northeast  \
# 0   19    1  27.900         0       1  16884.92400             False
# 1   18    0  33.770         1       0   1725.55230             False
# 2   28    0  33.000         3       0   4449.46200             False
# 3   33    0  22.705         0       0  21984.47061             False
# 4   32    0  28.880         0       0   3866.85520             False
#
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %%
#Scaling continuous features like age, bmi, and charges
#applying standardization 

#initialize thz scaler
scaler = MinMaxScaler()

#aapply scaling tp continous features
df[["age", "bmi", "charges"]] = scaler.fit_transform(df[["age", "bmi", "charges"]])

#check the transformed data 
print(df[["age", "bmi", "charges"]].head())
# Out:
#         age       bmi   charges
# 0  0.021739  0.321227  0.251611
# 1  0.000000  0.479150  0.009636
# 2  0.217391  0.458434  0.053115
# 3  0.326087  0.181464  0.333010
# 4  0.304348  0.347592  0.043816

# %%
#Split the data into training and testing sets 
x = df.drop(columns = ["charges"])
y = df["charges"]

#split the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

#check the size of the resulting datasets
print(f"Training data : {x_train.shape}, {y_train.shape}")
print(f"Testing data: {x_test.shape}, {y_test.shape}")
# Out:
# Training data : (2217, 9), (2217,)
# Testing data: (555, 9), (555,)

# %% [markdown]
# #### Feature selection and engineering

# %%
#identify key features impacting "charges" using correlation analysis or feature importance techniques

# %% [markdown]
# #### Model Selection

# %% [markdown]
# #### Model Training

# %% [markdown]
# #### Model Evaluation

# %% [markdown]
# #### Optimisation

# %% [markdown]
# #### Deployement
